# %%
#Imorting requests package to communicate with URL
import requests
#bs4 will help us parse the content of the html page
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from datetime import datetime
#Importing psycopg2 to access postgresql server and create DB and table
import psycopg2
from sqlalchemy import create_engine

# %%
#Creating empty lists for the elements we will scrape
address = [ ]
price = [ ]
bed = [ ]
amenities = [ ]

#Creating forloop to scrape 14 pages from site
for i in range(1,15):
    #set url and create headers to trick our site into thinking we are legitimate users
    url = f"https://www.apartments.com/austin-tx/min-1-bedrooms-800-to-1550/{i}/"
    headers={"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    #define response as requests.get and pass our url and headers through it to access the site and get the html content
    response = requests.get(url, headers=headers)
    response
    response = response.content
    #define our soup object as our html parser we are accessing through beautifulsoup and print our soup title to confirm we are accessing each url
    soup = bs(response,'html.parser')
    print(soup.title)
    #
    for div in soup.find_all('div', class_= "property-address js-url"):
        address.append(div.get_text(strip=True))
    for p in soup.find_all('p', class_= "property-pricing"):
        price.append(p.get_text(strip=True))
    for p in soup.find_all('p', class_= "property-beds"):
        bed.append(p.get_text(strip=True))
    for p in soup.find_all('p', class_="property-amenities"):
        amenities.append(p.get_text(strip=True, separator=", "))
    for div in soup.find_all('div',class_="property-information"):
        name = div.a['aria-label']
# Out:
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 2 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 3 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 4 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 5 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 6 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 7 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 8 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 9 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 10 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 11 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 12 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 13 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 14 | Apartments.com</title>

# %%
print('Total Names:',len(name))
print(name)
# Out:
# Total Names: 55
# Private bedroom in 3 bed/2 bath Home Unit A, Austin, TX

# %%
print('Total No Addresses:',len(address))
for a in address[:5]:
    print(a)
# Out:
# Total No Addresses: 560
# 8300 Bluff Springs Rd, Austin, TX 78744
# 4411 S Congress Ave, Austin, TX 78745
# 14115 N Highway 183, Austin, TX 78717
# 12217 N Interstate 35, Austin, TX 78753
# 12234 Heatherly Dr, Austin, TX 78747

# %%
print('Total No of Prices:',len(price))
for p in price[:5]:
    print(p)
# Out:
# Total No of Prices: 560
# $1,193 - 3,764
# $1,399 - 1,549
# $1,460 - 1,695
# $1,401 - 1,641
# $1,305 - 1,909

# %%
print('Total No of Beds:',len(bed))
for b in bed[:10]:
    print(b)
# Out:
# Total No of Beds: 560
# 1 Bed
# 1-2 Beds
# 1 Bed
# 1-3 Beds
# 1 Bed
# 1 Bed
# 1 Bed
# 1 Bed
# 1 Bed
# 1 Bed

# %%
print('Total No of amenities:',len(amenities))
for l in amenities[:5]:
    print(l)
# Out:
# Total No of amenities: 180
# Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Balcony, Package Service, EV Charging
# Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Walk-In Closets, Balcony, Stainless Steel Appliances, Package Service
# Dog & Cat Friendly, Fitness Center, Pool, Elevator
# Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Maintenance on site, Package Service, Elevator
# Dog & Cat Friendly, Stainless Steel Appliances, Package Service, Granite Countertops, Washer & Dryer Hookups

# %%
apartments = [ ]

for i in range(1,15):
    url = f"https://www.apartments.com/austin-tx/min-1-bedrooms-800-to-1550/{i}/"
    headers={"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    response = requests.get(url, headers=headers)
    response
    response = response.content
    soup = bs(response,'html.parser')
    print(soup.title)
    for listing in soup.find_all('li', class_= "mortar-wrapper"):
        apartment = {}
        for div in listing.find_all('div',class_="property-information"):
            apartment['name'] = div.a['aria-label']
        for div in listing.find_all('div', class_= "property-address js-url"):
            apartment['address'] = div.get_text(strip=True)
        for p in listing.find_all('p', class_= "property-pricing"):
            apartment['price'] = p.get_text(strip=True)
        for p in listing.find_all('p', class_= "property-beds"):
            apartment['beds'] = p.get_text(strip=True)
        for p in listing.find_all('p', class_="property-amenities"):
            apartment['amenities'] = p.get_text(strip=True, separator=", ")
        apartments.append(apartment)
# Out:
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 2 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,075 Rentals - Page 3 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 4 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 5 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 6 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 7 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 8 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 9 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 10 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 11 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 12 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 13 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,077 Rentals - Page 14 | Apartments.com</title>

# %%
print(len(apartments))
for apartment in apartments[:5]:
    print(apartment)
# Out:
# 560
# {'name': '44 South, Austin, TX', 'address': '4411 S Congress Ave, Austin, TX 78745', 'price': '$1,399 - 1,549', 'beds': '1-2 Beds', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Walk-In Closets, Balcony, Stainless Steel Appliances, Package Service'}
# {'name': 'Brightleaf at Lakeline, Austin, TX', 'address': '14115 N Highway 183, Austin, TX 78717', 'price': '$1,460 - 1,695', 'beds': '1 Bed', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, Elevator'}
# {'name': 'The Upland, Austin, TX', 'address': '12217 N Interstate 35, Austin, TX 78753', 'price': '$1,401 - 1,641', 'beds': '1-3 Beds', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Maintenance on site, Package Service, Elevator'}
# {'name': 'Water Oak, Austin, TX', 'address': '12234 Heatherly Dr, Austin, TX 78747', 'price': '$1,305 - 1,909', 'beds': '1 Bed', 'amenities': 'Dog & Cat Friendly, Stainless Steel Appliances, Package Service, Granite Countertops, Washer & Dryer Hookups'}
# {'name': 'The Prescott, Austin, TX', 'address': '8200 S Congress Ave, Austin, TX 78745', 'price': '$1,524 - 2,155', 'beds': '1 Bed', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Stainless Steel Appliances, Granite Countertops, EV Charging'}

# %%
apartments_df = pd.DataFrame(apartments)
apartments_df.head(5)
# Out:
#                                  name
# 0                44 South, Austin, TX  \
# 1  Brightleaf at Lakeline, Austin, TX
# 2              The Upland, Austin, TX
# 3               Water Oak, Austin, TX
# 4            The Prescott, Austin, TX
#
#                                    address           price      beds
# 0    4411 S Congress Ave, Austin, TX 78745  $1,399 - 1,549  1-2 Beds  \
# 1    14115 N Highway 183, Austin, TX 78717  $1,460 - 1,695     1 Bed
# 2  12217 N Interstate 35, Austin, TX 78753  $1,401 - 1,641  1-3 Beds
# 3     12234 Heatherly Dr, Austin, TX 78747  $1,305 - 1,909     1 Bed
# 4    8200 S Congress Ave, Austin, TX 78745  $1,524 - 2,155     1 Bed
#
#                                            amenities
# 0  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 1  Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3  Dog & Cat Friendly, Stainless Steel Appliances...
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...

# %%
apartments_df['name'] = apartments_df['name'].str.replace(r',[^,]*$', '',regex=True).astype(str)
apartments_df['name'] = apartments_df['name'].str.replace(r',[^,]*$', '',regex=True).astype(str)

# %%
apartments_df.head(20)
# Out:
#                                  name
# 0                            44 South  \
# 1              Brightleaf at Lakeline
# 2                          The Upland
# 3                           Water Oak
# 4                        The Prescott
# 5                Presidium Tech Ridge
# 6                         Avery Ranch
# 7                         Three Hills
# 8        Crestview Commons Apartments
# 9          Villages at East Riverside
# 10                Windsor Park Towers
# 11          Meritage at Steiner Ranch
# 12  Waters at Barton Creek Apartments
# 13             Cliffs at Barton Creek
# 14             Ellwood at Lake Travis
# 15           Marquis Lakeline Station
# 16        The District on La Frontera
# 17                              Riata
# 18          Estates at East Riverside
# 19               Starburst Apartments
#
#                                       address           price      beds
# 0       4411 S Congress Ave, Austin, TX 78745  $1,399 - 1,549  1-2 Beds  \
# 1       14115 N Highway 183, Austin, TX 78717  $1,460 - 1,695     1 Bed
# 2     12217 N Interstate 35, Austin, TX 78753  $1,401 - 1,641  1-3 Beds
# 3        12234 Heatherly Dr, Austin, TX 78747  $1,305 - 1,909     1 Bed
# 4       8200 S Congress Ave, Austin, TX 78745  $1,524 - 2,155     1 Bed
# 5     12210 Tech Ridge Blvd, Austin, TX 78753  $1,495 - 1,515     1 Bed
# 6     9225 N Lake Creek Pky, Austin, TX 78717  $1,399 - 2,959     1 Bed
# 7        12001 Heatherly Dr, Austin, TX 78747  $1,370 - 2,766     1 Bed
# 8           801 Sugaree Ave, Austin, TX 78757  $1,549 - 2,130     1 Bed
# 9          1301 Crossing Pl, Austin, TX 78741   Call for Rent    2 Beds
# 10     6007 N Interstate 35, Austin, TX 78723  $1,495 - 2,298     1 Bed
# 11  4500 Steiner Ranch Blvd, Austin, TX 78732  $1,281 - 1,481     1 Bed
# 12        2611 Bee Caves Rd, Austin, TX 78746  $1,359 - 1,469     1 Bed
# 13       3050 Tamarron Blvd, Austin, TX 78746  $1,474 - 3,436  1-3 Beds
# 14    7655 N Ranch Road 620, Austin, TX 78726  $1,185 - 1,660  1-3 Beds
# 15           13730 FM 620 N, Austin, TX 78717  $1,269 - 2,349  1-2 Beds
# 16    2811 La Frontera Blvd, Austin, TX 78728  $1,354 - 4,306  1-2 Beds
# 17    12300 Riata Trace Pky, Austin, TX 78727  $1,177 - 1,785     1 Bed
# 18         1300 Crossing Pl, Austin, TX 78741   Call for Rent    2 Beds
# 19     8800 N Interstate 35, Austin, TX 78753  $1,199 - 1,499     1 Bed
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 1   Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Dog & Cat Friendly, Stainless Steel Appliances...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, High...
# 11  Dog & Cat Friendly, Dishwasher, Walk-In Closet...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Pack...
# 13  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 14  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 15  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 17  Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 18  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 19  Fitness Center, Dishwasher, Refrigerator, In U...

# %%
#Cleaning and Seperating Address Column
apartments_df[['street', 'city', 'state/zip']] = apartments_df['address'].str.split(',', expand=True)

# %%
apartments_df.head(20)
# Out:
#                                  name
# 0                            44 South  \
# 1              Brightleaf at Lakeline
# 2                          The Upland
# 3                           Water Oak
# 4                        The Prescott
# 5                Presidium Tech Ridge
# 6                         Avery Ranch
# 7                         Three Hills
# 8        Crestview Commons Apartments
# 9          Villages at East Riverside
# 10                Windsor Park Towers
# 11          Meritage at Steiner Ranch
# 12  Waters at Barton Creek Apartments
# 13             Cliffs at Barton Creek
# 14             Ellwood at Lake Travis
# 15           Marquis Lakeline Station
# 16        The District on La Frontera
# 17                              Riata
# 18          Estates at East Riverside
# 19               Starburst Apartments
#
#                                       address           price      beds
# 0       4411 S Congress Ave, Austin, TX 78745  $1,399 - 1,549  1-2 Beds  \
# 1       14115 N Highway 183, Austin, TX 78717  $1,460 - 1,695     1 Bed
# 2     12217 N Interstate 35, Austin, TX 78753  $1,401 - 1,641  1-3 Beds
# 3        12234 Heatherly Dr, Austin, TX 78747  $1,305 - 1,909     1 Bed
# 4       8200 S Congress Ave, Austin, TX 78745  $1,524 - 2,155     1 Bed
# 5     12210 Tech Ridge Blvd, Austin, TX 78753  $1,495 - 1,515     1 Bed
# 6     9225 N Lake Creek Pky, Austin, TX 78717  $1,399 - 2,959     1 Bed
# 7        12001 Heatherly Dr, Austin, TX 78747  $1,370 - 2,766     1 Bed
# 8           801 Sugaree Ave, Austin, TX 78757  $1,549 - 2,130     1 Bed
# 9          1301 Crossing Pl, Austin, TX 78741   Call for Rent    2 Beds
# 10     6007 N Interstate 35, Austin, TX 78723  $1,495 - 2,298     1 Bed
# 11  4500 Steiner Ranch Blvd, Austin, TX 78732  $1,281 - 1,481     1 Bed
# 12        2611 Bee Caves Rd, Austin, TX 78746  $1,359 - 1,469     1 Bed
# 13       3050 Tamarron Blvd, Austin, TX 78746  $1,474 - 3,436  1-3 Beds
# 14    7655 N Ranch Road 620, Austin, TX 78726  $1,185 - 1,660  1-3 Beds
# 15           13730 FM 620 N, Austin, TX 78717  $1,269 - 2,349  1-2 Beds
# 16    2811 La Frontera Blvd, Austin, TX 78728  $1,354 - 4,306  1-2 Beds
# 17    12300 Riata Trace Pky, Austin, TX 78727  $1,177 - 1,785     1 Bed
# 18         1300 Crossing Pl, Austin, TX 78741   Call for Rent    2 Beds
# 19     8800 N Interstate 35, Austin, TX 78753  $1,199 - 1,499     1 Bed
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, In U...  \
# 1   Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Dog & Cat Friendly, Stainless Steel Appliances...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, High...
# 11  Dog & Cat Friendly, Dishwasher, Walk-In Closet...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Pack...
# 13  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 14  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 15  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 17  Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 18  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 19  Fitness Center, Dishwasher, Refrigerator, In U...
#
#                      street     city  state/zip
# 0       4411 S Congress Ave   Austin   TX 78745
# 1       14115 N Highway 183   Austin   TX 78717
# 2     12217 N Interstate 35   Austin   TX 78753
# 3        12234 Heatherly Dr   Austin   TX 78747
# 4       8200 S Congress Ave   Austin   TX 78745
# 5     12210 Tech Ridge Blvd   Austin   TX 78753
# 6     9225 N Lake Creek Pky   Austin   TX 78717
# 7        12001 Heatherly Dr   Austin   TX 78747
# 8           801 Sugaree Ave   Austin   TX 78757
# 9          1301 Crossing Pl   Austin   TX 78741
# 10     6007 N Interstate 35   Austin   TX 78723
# 11  4500 Steiner Ranch Blvd   Austin   TX 78732
# 12        2611 Bee Caves Rd   Austin   TX 78746
# 13       3050 Tamarron Blvd   Austin   TX 78746
# 14    7655 N Ranch Road 620   Austin   TX 78726
# 15           13730 FM 620 N   Austin   TX 78717
# 16    2811 La Frontera Blvd   Austin   TX 78728
# 17    12300 Riata Trace Pky   Austin   TX 78727
# 18         1300 Crossing Pl   Austin   TX 78741
# 19     8800 N Interstate 35   Austin   TX 78753

# %%
apts_df_new = apartments_df['state/zip'].str.split(' ', expand=True)
apts_df_new.columns = ['index','state', 'zip']
apartments_df[['state','zipcode']] = apts_df_new[['state','zip']]
apartments_df = apartments_df.drop(columns=['state/zip'])

# %%
apartments_df.head()
# Out:
#                      name                                  address
# 0                44 South    4411 S Congress Ave, Austin, TX 78745  \
# 1  Brightleaf at Lakeline    14115 N Highway 183, Austin, TX 78717
# 2              The Upland  12217 N Interstate 35, Austin, TX 78753
# 3               Water Oak     12234 Heatherly Dr, Austin, TX 78747
# 4            The Prescott    8200 S Congress Ave, Austin, TX 78745
#
#             price      beds
# 0  $1,399 - 1,549  1-2 Beds  \
# 1  $1,460 - 1,695     1 Bed
# 2  $1,401 - 1,641  1-3 Beds
# 3  $1,305 - 1,909     1 Bed
# 4  $1,524 - 2,155     1 Bed
#
#                                            amenities                 street
# 0  Dog & Cat Friendly, Fitness Center, Pool, In U...    4411 S Congress Ave  \
# 1  Dog & Cat Friendly, Fitness Center, Pool, Elev...    14115 N Highway 183
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...  12217 N Interstate 35
# 3  Dog & Cat Friendly, Stainless Steel Appliances...     12234 Heatherly Dr
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...    8200 S Congress Ave
#
#       city state zipcode
# 0   Austin    TX   78745
# 1   Austin    TX   78717
# 2   Austin    TX   78753
# 3   Austin    TX   78747
# 4   Austin    TX   78745

# %%
#Cleaning Price Columns
apartments_df[['minprice', 'maxprice']] = apartments_df['price'].str.split('-', expand=True)
apartments_df['minprice'] = apartments_df['minprice'].str.replace('$','',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace('$','',)
apartments_df['minprice'] = apartments_df['minprice'].str.replace(',','',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace(',','',)
apartments_df = apartments_df.drop(columns=['price'])

# %%
apartments_df.head(10)
# Out:
#                            name                                  address
# 0                      44 South    4411 S Congress Ave, Austin, TX 78745  \
# 1        Brightleaf at Lakeline    14115 N Highway 183, Austin, TX 78717
# 2                    The Upland  12217 N Interstate 35, Austin, TX 78753
# 3                     Water Oak     12234 Heatherly Dr, Austin, TX 78747
# 4                  The Prescott    8200 S Congress Ave, Austin, TX 78745
# 5          Presidium Tech Ridge  12210 Tech Ridge Blvd, Austin, TX 78753
# 6                   Avery Ranch  9225 N Lake Creek Pky, Austin, TX 78717
# 7                   Three Hills     12001 Heatherly Dr, Austin, TX 78747
# 8  Crestview Commons Apartments        801 Sugaree Ave, Austin, TX 78757
# 9    Villages at East Riverside       1301 Crossing Pl, Austin, TX 78741
#
#        beds                                          amenities
# 0  1-2 Beds  Dog & Cat Friendly, Fitness Center, Pool, In U...  \
# 1     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 2  1-3 Beds  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3     1 Bed  Dog & Cat Friendly, Stainless Steel Appliances...
# 4     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 6     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 8     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9    2 Beds  Dog & Cat Friendly, Fitness Center, Pool, In U...
#
#                   street     city state zipcode       minprice maxprice
# 0    4411 S Congress Ave   Austin    TX   78745          1399      1549
# 1    14115 N Highway 183   Austin    TX   78717          1460      1695
# 2  12217 N Interstate 35   Austin    TX   78753          1401      1641
# 3     12234 Heatherly Dr   Austin    TX   78747          1305      1909
# 4    8200 S Congress Ave   Austin    TX   78745          1524      2155
# 5  12210 Tech Ridge Blvd   Austin    TX   78753          1495      1515
# 6  9225 N Lake Creek Pky   Austin    TX   78717          1399      2959
# 7     12001 Heatherly Dr   Austin    TX   78747          1370      2766
# 8        801 Sugaree Ave   Austin    TX   78757          1549      2130
# 9       1301 Crossing Pl   Austin    TX   78741  Call for Rent     None

# %%
apartments_df['minprice'] = apartments_df['minprice'].str.replace('Call for Rent','0',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace('Call for Rent','0',)

# %%
#Cleaning bedroom column
apartments_df[['minbed', 'maxbed']] = apartments_df['beds'].str.split('-', expand=True)
apartments_df['minbed'] = apartments_df['minbed'].str.replace('Beds','',)
apartments_df['minbed'] = apartments_df['minbed'].str.replace('Bed','',)
apartments_df['maxbed'] = apartments_df['maxbed'].str.replace('Beds','',)
apartments_df['maxbed'] = apartments_df['maxbed'].str.replace('Bed','',)
apartments_df = apartments_df.drop(columns=['beds'])

# %%
apartments_df = apartments_df.fillna(0)

# %%
today = datetime.now()
print(today)
date = today.strftime("%d/%m/%Y %H:%M:%S")
date
# Out:
# 2023-10-25 18:16:07.305945
# '25/10/2023 18:16:07'

# %%
apartments_df['building_type'] = 'APT'
apartments_df['date'] = date

# %%
apartments_df.head(5)
# Out:
#                      name                                  address
# 0                44 South    4411 S Congress Ave, Austin, TX 78745  \
# 1  Brightleaf at Lakeline    14115 N Highway 183, Austin, TX 78717
# 2              The Upland  12217 N Interstate 35, Austin, TX 78753
# 3               Water Oak     12234 Heatherly Dr, Austin, TX 78747
# 4            The Prescott    8200 S Congress Ave, Austin, TX 78745
#
#                                            amenities                 street
# 0  Dog & Cat Friendly, Fitness Center, Pool, In U...    4411 S Congress Ave  \
# 1  Dog & Cat Friendly, Fitness Center, Pool, Elev...    14115 N Highway 183
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...  12217 N Interstate 35
# 3  Dog & Cat Friendly, Stainless Steel Appliances...     12234 Heatherly Dr
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...    8200 S Congress Ave
#
#       city state zipcode minprice maxprice minbed maxbed building_type
# 0   Austin    TX   78745    1399      1549      1     2            APT  \
# 1   Austin    TX   78717    1460      1695     1       0           APT
# 2   Austin    TX   78753    1401      1641      1     3            APT
# 3   Austin    TX   78747    1305      1909     1       0           APT
# 4   Austin    TX   78745    1524      2155     1       0           APT
#
#                   date
# 0  25/10/2023 18:16:07
# 1  25/10/2023 18:16:07
# 2  25/10/2023 18:16:07
# 3  25/10/2023 18:16:07
# 4  25/10/2023 18:16:07

# %%
apartments_df['city'].value_counts()
# Out:
# city
#  Austin          516
#  Pflugerville     15
#  Cedar Park       14
#  Round Rock        6
#  Del Valle         3
#  Manor             3
#  AUSTIN            2
#  Manchaca          1
# Name: count, dtype: int64

# %%
apartments_df.dtypes
# Out:
# name             object
# address          object
# amenities        object
# street           object
# city             object
# state            object
# zipcode          object
# minprice         object
# maxprice         object
# minbed           object
# maxbed           object
# building_type    object
# date             object
# dtype: object

# %%
convert_dict = {'minprice': float,
                'maxprice': float,
                'minbed': int,
                'maxbed': int,
                }
apartments_df = apartments_df.astype(convert_dict)
apartments_df['date'] = apartments_df['date'].astype('datetime64[ns]')
print(apartments_df.dtypes)
# Out:
# name                     object
# address                  object
# amenities                object
# street                   object
# city                     object
# state                    object
# zipcode                  object
# minprice                float64
# maxprice                float64
# minbed                    int64
# maxbed                    int64
# building_type            object
# date             datetime64[ns]
# dtype: object
# /var/folders/0k/r3nvlvy97cgdhjrb4v697trw0000gn/T/ipykernel_28917/1689935638.py:7: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   apartments_df['date'] = apartments_df['date'].astype('datetime64[ns]')

# %%
apartments_df.head(20)
# Out:
#                                  name
# 0                            44 South  \
# 1              Brightleaf at Lakeline
# 2                          The Upland
# 3                           Water Oak
# 4                        The Prescott
# 5                Presidium Tech Ridge
# 6                         Avery Ranch
# 7                         Three Hills
# 8        Crestview Commons Apartments
# 9          Villages at East Riverside
# 10                Windsor Park Towers
# 11          Meritage at Steiner Ranch
# 12  Waters at Barton Creek Apartments
# 13             Cliffs at Barton Creek
# 14             Ellwood at Lake Travis
# 15           Marquis Lakeline Station
# 16        The District on La Frontera
# 17                              Riata
# 18          Estates at East Riverside
# 19               Starburst Apartments
#
#                                       address
# 0       4411 S Congress Ave, Austin, TX 78745  \
# 1       14115 N Highway 183, Austin, TX 78717
# 2     12217 N Interstate 35, Austin, TX 78753
# 3        12234 Heatherly Dr, Austin, TX 78747
# 4       8200 S Congress Ave, Austin, TX 78745
# 5     12210 Tech Ridge Blvd, Austin, TX 78753
# 6     9225 N Lake Creek Pky, Austin, TX 78717
# 7        12001 Heatherly Dr, Austin, TX 78747
# 8           801 Sugaree Ave, Austin, TX 78757
# 9          1301 Crossing Pl, Austin, TX 78741
# 10     6007 N Interstate 35, Austin, TX 78723
# 11  4500 Steiner Ranch Blvd, Austin, TX 78732
# 12        2611 Bee Caves Rd, Austin, TX 78746
# 13       3050 Tamarron Blvd, Austin, TX 78746
# 14    7655 N Ranch Road 620, Austin, TX 78726
# 15           13730 FM 620 N, Austin, TX 78717
# 16    2811 La Frontera Blvd, Austin, TX 78728
# 17    12300 Riata Trace Pky, Austin, TX 78727
# 18         1300 Crossing Pl, Austin, TX 78741
# 19     8800 N Interstate 35, Austin, TX 78753
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, In U...  \
# 1   Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Dog & Cat Friendly, Stainless Steel Appliances...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Club...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, High...
# 11  Dog & Cat Friendly, Dishwasher, Walk-In Closet...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Pack...
# 13  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 14  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 15  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 17  Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 18  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 19  Fitness Center, Dishwasher, Refrigerator, In U...
#
#                      street     city state zipcode  minprice  maxprice
# 0       4411 S Congress Ave   Austin    TX   78745    1399.0    1549.0  \
# 1       14115 N Highway 183   Austin    TX   78717    1460.0    1695.0
# 2     12217 N Interstate 35   Austin    TX   78753    1401.0    1641.0
# 3        12234 Heatherly Dr   Austin    TX   78747    1305.0    1909.0
# 4       8200 S Congress Ave   Austin    TX   78745    1524.0    2155.0
# 5     12210 Tech Ridge Blvd   Austin    TX   78753    1495.0    1515.0
# 6     9225 N Lake Creek Pky   Austin    TX   78717    1399.0    2959.0
# 7        12001 Heatherly Dr   Austin    TX   78747    1370.0    2766.0
# 8           801 Sugaree Ave   Austin    TX   78757    1549.0    2130.0
# 9          1301 Crossing Pl   Austin    TX   78741       0.0       0.0
# 10     6007 N Interstate 35   Austin    TX   78723    1495.0    2298.0
# 11  4500 Steiner Ranch Blvd   Austin    TX   78732    1281.0    1481.0
# 12        2611 Bee Caves Rd   Austin    TX   78746    1359.0    1469.0
# 13       3050 Tamarron Blvd   Austin    TX   78746    1474.0    3436.0
# 14    7655 N Ranch Road 620   Austin    TX   78726    1185.0    1660.0
# 15           13730 FM 620 N   Austin    TX   78717    1269.0    2349.0
# 16    2811 La Frontera Blvd   Austin    TX   78728    1354.0    4306.0
# 17    12300 Riata Trace Pky   Austin    TX   78727    1177.0    1785.0
# 18         1300 Crossing Pl   Austin    TX   78741       0.0       0.0
# 19     8800 N Interstate 35   Austin    TX   78753    1199.0    1499.0
#
#     minbed  maxbed building_type                date
# 0        1       2           APT 2023-10-25 18:16:07
# 1        1       0           APT 2023-10-25 18:16:07
# 2        1       3           APT 2023-10-25 18:16:07
# 3        1       0           APT 2023-10-25 18:16:07
# 4        1       0           APT 2023-10-25 18:16:07
# 5        1       0           APT 2023-10-25 18:16:07
# 6        1       0           APT 2023-10-25 18:16:07
# 7        1       0           APT 2023-10-25 18:16:07
# 8        1       0           APT 2023-10-25 18:16:07
# 9        2       0           APT 2023-10-25 18:16:07
# 10       1       0           APT 2023-10-25 18:16:07
# 11       1       0           APT 2023-10-25 18:16:07
# 12       1       0           APT 2023-10-25 18:16:07
# 13       1       3           APT 2023-10-25 18:16:07
# 14       1       3           APT 2023-10-25 18:16:07
# 15       1       2           APT 2023-10-25 18:16:07
# 16       1       2           APT 2023-10-25 18:16:07
# 17       1       0           APT 2023-10-25 18:16:07
# 18       2       0           APT 2023-10-25 18:16:07
# 19       1       0           APT 2023-10-25 18:16:07

# %%
e = today.strftime("%d.%m.%Y")
print(e)
fname = "./Addresses/addresses_{}.xlsx".format(e)
print(fname)
apartments_df.to_excel(fname)
# Out:
# 25.10.2023
# ./Addresses/addresses_25.10.2023.xlsx

# %% [markdown]
# SAVE TABLE TO SQL

# %%
hostname = 'localhost'
database = 'geo'
username = 'postgres'
pwd = '032197An'
port_id = 5432

# %%
try:    
    conn = psycopg2.connect(
        host = hostname,
        dbname = database,
        user = username,
        password = pwd,
        port = port_id)
except Exception as error:
    print(error)

# %%
cur = conn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
#Created a new database to in SQL to store the date
#cur.execute('CREATE DATABASE austin')

# %%
#Deleted any tables named austin if they existed
#cur.execute('DROP TABLE IF EXISTS apartments')

# %%
#Created new table in database to collect the data in the dataframe
#cur.execute("CREATE TABLE IF NOT EXISTS apartments (name VARCHAR(256), address VARCHAR(256),amenities VARCHAR(256), street VARCHAR(256), city VARCHAR(256), state VARCHAR(5), zipcode VARCHAR(10), minprice FLOAT, maxprice FLOAT, minbed INT, maxbed INT, building_type VARCHAR(5), date TIMESTAMP)")

# %%
#Need to research more about this,
engine = create_engine('postgresql+psycopg2://postgres:032197An@localhost/geo')
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/geo)

# %%
apartments_df.to_sql('austin_apartments', engine, if_exists='append', index=False)
# Out:
# 560

# %%
conn.commit
# Out:
# <function connection.commit>

# %%
conn.close()
