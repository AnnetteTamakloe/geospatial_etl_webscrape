# %%
#Imorting requests package to communicate with URL
import requests
#bs4 will help us parse the content of the html page
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from datetime import datetime
#Importing psycopg2 to access postgresql server and create DB and table
import psycopg2
from sqlalchemy import create_engine

# %%
df = pd.read_excel('Addresses/stores.xlsx')

# %%
df = df.rename(columns={"address": "street", "zip":"zipcode"})

# %%
df
# Out:
#              type              name                                  street
# 0   Grocery Store       Trader Joes                  9722 Great Hills Trail  \
# 1   Grocery Store       Trader Joes                        2805 Bee Cave Rd
# 2   Grocery Store       Trader Joes          211 Walter Seaholm Dr, Ste 100
# 3   Grocery Store        Sam's Club                     4970 W. Highway 290
# 4   Grocery Store        Sam's Club                    9900 S Interstate 35
# 5   Grocery Store        Sam's Club             9700 N Capital Of Texas Hwy
# 6   Grocery Store        Sam's Club                  10901 Lakeline Mall Dr
# 7   Grocery Store        Sam's Club                           1350 Leah Ave
# 8   Grocery Store            Costco     4301 W William Cannon Dr Bldg A Ste
# 9   Grocery Store            Costco                     10401 Research Blvd
# 10  Grocery Store            Costco                           1901 Kelly Ln
# 11  Grocery Store            Costco                       4601 183A Toll Rd
# 12  Grocery Store       Whole Foods                         11920 Domain Dr
# 13  Grocery Store       Whole Foods             9607 Research Blvd, Ste 300
# 14  Grocery Store       Whole Foods   4301 W William Cannon, Bldg B Ste 800
# 15  Grocery Store       Whole Foods                   901 E 5Th St, Ste 100
# 16  Grocery Store       Whole Foods                        525 N Lamar Blvd
# 17  Grocery Store               HEB           11521 North Fm620, Building A
# 18  Grocery Store               HEB              14028 North Us 183, Austin
# 19  Grocery Store               HEB             2508 E Riverside Dr, Austin
# 20  Grocery Store               HEB                   2652 Lake Austin Blvd
# 21  Grocery Store               HEB  2301 S.Congress Ave.\nAustin, Tx 78704
# 22  Grocery Store               HEB                           2701 East 7Th
# 23  Grocery Store               HEB                         1601 Trinity St
# 24  Grocery Store               HEB                        1000 East 41 St.
# 25  Grocery Store               HEB                      1801 E.51St Street
# 26  Grocery Store               HEB                          5808 Burnet Rd
# 27  Grocery Store               HEB          701 Capital Of Texas Hwy-Bld C
# 28  Grocery Store               HEB                        6607 South Ih 35
# 29  Grocery Store               HEB                  7112 Ed Bluestein_#125
# 30  Grocery Store               HEB                    7015 Village Ctr Dr.
# 31  Grocery Store               HEB                        6900 Brodie Lane
# 32  Grocery Store               HEB                       9414 N Lamar Blvd
# 33  Grocery Store               HEB              8801 South Congress Avenue
# 34  Grocery Store               HEB                  2110 West Slaughter Ln
# 35  Grocery Store               HEB                             7901 Us-290
# 36  Grocery Store               HEB            10710 Research Blvd. Ste 200
# 37  Grocery Store               HEB                  5800 W. Slaughter Lane
# 38  Grocery Store               HEB                    500 Canyon Ridge Dr.
# 39  Grocery Store               HEB                    12407 N. Mopac Expwy
# 40  Grocery Store               HEB                           7301 N Fm 620
# 41  Grocery Store               HEB                      12400 W Highway 71
# 42  Grocery Store               HEB                     12860 Research Blvd
# 43  Grocery Store               HEB                   6001 West Parmer Lane
# 44  Grocery Store               HEB                  1434 Wells Branch Pkwy
# 45  Grocery Store               HEB                           15300 S Ih-35
# 46  Grocery Store               HEB           11521 North Fm620, Building A
# 47  Grocery Store               HEB                            201 N Fm 685
# 48  Grocery Store               HEB                          12021 W Us 290
# 49  Grocery Store               HEB                   2000 Ranch Road 620 S
# 50  Grocery Store               HEB                      14028 North Us 183
# 51  Grocery Store               HEB            603 Louis Henna Blvd. Bldg A
# 52  Grocery Store               HEB                    16900 Ranch Road 620
# 53  Grocery Store               HEB                   3750 Gattis School Rd
# 54  Grocery Store               HEB              1700 East Palm Valley Blvd
# 55  Grocery Store               HEB                   170 E Whitestone Blvd
# 56  Grocery Store               HEB                    2800 East Whitestone
# 57  Grocery Store               HEB                   5000 Gattis School Rd
# 58  Grocery Store               HEB                      5401 South Fm 1626
# 59  Grocery Store               HEB                    250 University Blvd.
# 60  Grocery Store               HEB                        598 E.Hwy Us 290
# 61  Grocery Store               HEB                       1080 East Hwy 290
# 62  Grocery Store               HEB                       651 N. Us Hwy 183
# 63  Grocery Store               HEB                 1010 W. University Ave.
# 64  Grocery Store               HEB            19344 Ronald W. Reagan Blvd.
# 65  Grocery Store               HEB              19348 Ronald W.Reagan Blvd
# 66        Theatre      Regal Cinema                       4477 S Lamar Blvd
# 67        Theatre      Regal Cinema                     901 Little Texas Ln
# 68        Theatre      Regal Cinema                     9700 Stonelake Blvd
# 69        Theatre  Alamo Drafthouse            2700 W Anderson Ln. Unit 701
# 70        Theatre  Alamo Drafthouse                    1911 Aldrich St #120
# 71        Theatre  Alamo Drafthouse                       1120 S Lamar Blvd
# 72        Theatre  Alamo Drafthouse             14028 Us-183 Hwy Building F
# 73        Theatre  Alamo Drafthouse                5701 W Slaughter Ln A130
# 74        Theatre          Cinemark     9900 S Ih-35 Service Road Sb Unit N
# 75        Theatre          Cinemark                            15436 Fm1825
# 76        Theatre          Cinemark                 12812 Hill Country Blvd
#
#                 city state zipcode country
# 0             Austin    TX   78759      U.S
# 1             Austin   TX   78746       U.S
# 2             Austin   TX    78701      U.S
# 3             Austin   TX    78735      U.S
# 4             Austin   TX    78748      U.S
# 5             Austin   TX    78759      U.S
# 6             Austin   TX    78717      U.S
# 7         San Marcos    TX   78666      U.S
# 8             Austin    TX   78749      U.S
# 9             Austin    TX   78759      U.S
# 10      Pflugerville    TX   78660      U.S
# 11        Cedar Park    TX   78613      U.S
# 12            Austin    TX   78758      U.S
# 13            Austin    TX   78759      U.S
# 14            Austin    TX   78749      U.S
# 15            Austin    TX   78702      U.S
# 16            Austin    TX   78703      U.S
# 17            Austin    TX   78726      U.S
# 18            Austin    TX   78717      U.S
# 19            Austin    TX   78741      U.S
# 20            Austin    TX   78703      U.S
# 21            Austin    TX   78704      U.S
# 22            Austin    TX   78702      U.S
# 23            Austin    TX   78712      U.S
# 24            Austin    TX   78751      U.S
# 25            Austin    TX   78723      U.S
# 26            Austin    TX   78756      U.S
# 27   West Lake Hills    TX   78746      U.S
# 28            Austin    TX   78744      U.S
# 29            Austin    TX   78723      U.S
# 30            Austin    TX   78731      U.S
# 31            Austin    TX   78745      U.S
# 32            Austin    TX   78753      U.S
# 33            Austin    TX   78745      U.S
# 34            Austin    TX   78748      U.S
# 35            Austin    TX   78736      U.S
# 36            Austin    TX   78759      U.S
# 37            Austin    TX   78749      U.S
# 38            Austin    TX   78753      U.S
# 39            Austin    TX   78758      U.S
# 40            Austin    TX   78726      U.S
# 41            Austin    TX   78738      U.S
# 42            Austin    TX   78750      U.S
# 43            Austin    TX   78727      U.S
# 44            Austin    TX   78660      U.S
# 45              Buda    TX   78610      U.S
# 46            Austin    TX   78726      U.S
# 47      Pflugerville    TX   78660      U.S
# 48            Austin    TX   78737      U.S
# 49           Lakeway    TX   78734      U.S
# 50            Austin    TX   78717      U.S
# 51        Round Rock    TX   78664      U.S
# 52        Round Rock    TX   78681      U.S
# 53        Round Rock    TX   78664      U.S
# 54        Round Rock    TX   78664      U.S
# 55        Cedar Park    TX   78613      U.S
# 56        Cedar Park    TX   78613      U.S
# 57             Hutto    TX   78634      U.S
# 58              Kyle    TX   78640      U.S
# 59        Round Rock    TX   78665      U.S
# 60  Dripping Springs    TX   78620      U.S
# 61             Elgin    TX   78621      U.S
# 62           Leander    TX   78641      U.S
# 63        Georgetown    TX   78628      U.S
# 64        Georgetown    TX   78628      U.S
# 65        Georgetown    TX   78628      U.S
# 66            Austin    TX   78745      U.S
# 67            Austin    TX   78745      U.S
# 68            Austin    TX   78759      U.S
# 69            Austin    TX   78757      U.S
# 70            Austin    TX   78723      U.S
# 71            Austin    TX   78704      U.S
# 72            Austin    TX   78717      U.S
# 73            Austin    TX   78749      U.S
# 74            Austin    TX   78748      U.S
# 75      Pflugerville    TX   78660      U.S
# 76          Bee Cave    TX   78738      U.S

# %%
hostname = 'localhost'
database = 'geo'
username = 'postgres'
pwd = '032197An'
port_id = 5432

# %%
try:    
    conn = psycopg2.connect(
        host = hostname,
        dbname = database,
        user = username,
        password = pwd,
        port = port_id)
except Exception as error:
    print(error)

# %%
cur = conn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
#Created a new database to in SQL to store the date
#cur.execute('CREATE DATABASE stores')

# %%
#Created new table in database to collect the data in the dataframe
cur.execute("CREATE TABLE IF NOT EXISTS stores (type VARCHAR(256), name VARCHAR(256), street VARCHAR(256), city VARCHAR(256), state VARCHAR(5), zipcode VARCHAR(10), country VARCHAR(5))")

# %%
engine = create_engine('postgresql+psycopg2://postgres:032197An@localhost/geo')
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/geo)

# %%
df.to_sql('austin_stores', engine, if_exists='append', index=False)
# Out:
# 77

# %%
conn.commit
# Out:
# <function connection.commit>

# %%
conn.close()
