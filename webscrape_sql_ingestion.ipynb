# %%
#Imorting requests package to communicate with URL
import requests
#bs4 will help us parse the content of the html page
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from datetime import datetime
#Importing psycopg2 to access postgresql server and create DB and table
import psycopg2
from sqlalchemy import create_engine

# %%
#Creating empty lists for the elements we will scrape
address = [ ]
price = [ ]
bed = [ ]
amenities = [ ]

#Creating forloop to scrape 14 pages from site
for i in range(1,15):
    #set url and create headers to trick our site into thinking we are legitimate users
    url = f"https://www.apartments.com/austin-tx/min-1-bedrooms-800-to-1550/{i}/"
    headers={"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    #define response as requests.get and pass our url and headers through it to access the site and get the html content
    response = requests.get(url, headers=headers)
    response
    response = response.content
    #define our soup object as our html parser we are accessing through beautifulsoup and print our soup title to confirm we are accessing each url
    soup = bs(response,'html.parser')
    print(soup.title)
    #
    for div in soup.find_all('div', class_= "property-address js-url"):
        address.append(div.get_text(strip=True))
    for p in soup.find_all('p', class_= "property-pricing"):
        price.append(p.get_text(strip=True))
    for p in soup.find_all('p', class_= "property-beds"):
        bed.append(p.get_text(strip=True))
    for p in soup.find_all('p', class_="property-amenities"):
        amenities.append(p.get_text(strip=True, separator=", "))
    for div in soup.find_all('div',class_="property-information"):
        name = div.a['aria-label']
# Out:
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 2 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 3 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 4 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 5 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 6 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 7 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 8 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 9 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 10 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 11 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 12 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 13 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 14 | Apartments.com</title>

# %%
print('Total Names:',len(name))
print(name)
# Out:
# Total Names: 55
# Private bedroom in 3 bed/2 bath Home Unit A, Austin, TX

# %%
print('Total No Addresses:',len(address))
for a in address[:5]:
    print(a)
# Out:
# Total No Addresses: 560
# 2811 La Frontera Blvd, Austin, TX 78728
# 12300 Riata Trace Pky, Austin, TX 78727
# 1300 Crossing Pl, Austin, TX 78741
# 8800 N Interstate 35, Austin, TX 78753
# 4711 E Riverside Dr, Austin, TX 78741

# %%
print('Total No of Prices:',len(price))
for p in price[:5]:
    print(p)
# Out:
# Total No of Prices: 560
# $1,354 - 4,306
# $1,177 - 1,785
# Call for Rent
# $1,199 - 1,499
# $1,399 - 1,699

# %%
print('Total No of Beds:',len(bed))
for b in bed[:10]:
    print(b)
# Out:
# Total No of Beds: 560
# 1-2 Beds
# 1 Bed
# 2 Beds
# 1 Bed
# 1 Bed
# 1-2 Beds
# 1 Bed
# 1 Bed
# 1-2 Beds
# 1 Bed

# %%
print('Total No of amenities:',len(amenities))
for l in amenities[:5]:
    print(l)
# Out:
# Total No of amenities: 180
# Dog & Cat Friendly, Fitness Center, Pool, Dishwasher, Refrigerator, Kitchen, In Unit Washer & Dryer, Walk-In Closets
# Dog & Cat Friendly, Fitness Center, In Unit Washer & Dryer, Maintenance on site, Package Service, EV Charging
# Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, High-Speed Internet, Stainless Steel Appliances, Gated
# Fitness Center, Dishwasher, Refrigerator, In Unit Washer & Dryer, Clubhouse, Balcony, Range, Maintenance on site
# Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Stainless Steel Appliances, Business Center, Granite Countertops, Rooftop Deck

# %%
apartments = [ ]

for i in range(1,15):
    url = f"https://www.apartments.com/austin-tx/min-1-bedrooms-800-to-1550/{i}/"
    headers={"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    response = requests.get(url, headers=headers)
    response
    response = response.content
    soup = bs(response,'html.parser')
    print(soup.title)
    for listing in soup.find_all('li', class_= "mortar-wrapper"):
        apartment = {}
        for div in listing.find_all('div',class_="property-information"):
            apartment['name'] = div.a['aria-label']
        for div in listing.find_all('div', class_= "property-address js-url"):
            apartment['address'] = div.get_text(strip=True)
        for p in listing.find_all('p', class_= "property-pricing"):
            apartment['price'] = p.get_text(strip=True)
        for p in listing.find_all('p', class_= "property-beds"):
            apartment['beds'] = p.get_text(strip=True)
        for p in listing.find_all('p', class_="property-amenities"):
            apartment['amenities'] = p.get_text(strip=True, separator=", ")
        apartments.append(apartment)
# Out:
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 2 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 3 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 4 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 5 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 6 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 7 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 8 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 9 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 10 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 11 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 12 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 13 | Apartments.com</title>
# <title> 1 Bedroom Apartments under $1,550 in Austin, TX - 10,085 Rentals - Page 14 | Apartments.com</title>

# %%
print(len(apartments))
for apartment in apartments[:5]:
    print(apartment)
# Out:
# 560
# {'name': 'The District on La Frontera, Austin, TX', 'address': '2811 La Frontera Blvd, Austin, TX 78728', 'price': '$1,354 - 4,306', 'beds': '1-2 Beds', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, Dishwasher, Refrigerator, Kitchen, In Unit Washer & Dryer, Walk-In Closets'}
# {'name': 'Riata, Austin, TX', 'address': '12300 Riata Trace Pky, Austin, TX 78727', 'price': '$1,177 - 1,785', 'beds': '1 Bed', 'amenities': 'Dog & Cat Friendly, Fitness Center, In Unit Washer & Dryer, Maintenance on site, Package Service, EV Charging'}
# {'name': 'Estates at East Riverside, Austin, TX', 'address': '1300 Crossing Pl, Austin, TX 78741', 'price': 'Call for Rent', 'beds': '2 Beds', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, High-Speed Internet, Stainless Steel Appliances, Gated'}
# {'name': 'Starburst Apartments, Austin, TX', 'address': '8800 N Interstate 35, Austin, TX 78753', 'price': '$1,199 - 1,499', 'beds': '1 Bed', 'amenities': 'Fitness Center, Dishwasher, Refrigerator, In Unit Washer & Dryer, Clubhouse, Balcony, Range, Maintenance on site'}
# {'name': 'Edison Riverside, Austin, TX', 'address': '4711 E Riverside Dr, Austin, TX 78741', 'price': '$1,399 - 1,699', 'beds': '1 Bed', 'amenities': 'Dog & Cat Friendly, Fitness Center, Pool, In Unit Washer & Dryer, Stainless Steel Appliances, Business Center, Granite Countertops, Rooftop Deck'}

# %%
apartments_df = pd.DataFrame(apartments)
apartments_df.head(5)
# Out:
#                                       name
# 0  The District on La Frontera, Austin, TX  \
# 1                        Riata, Austin, TX
# 2    Estates at East Riverside, Austin, TX
# 3         Starburst Apartments, Austin, TX
# 4             Edison Riverside, Austin, TX
#
#                                    address           price      beds
# 0  2811 La Frontera Blvd, Austin, TX 78728  $1,354 - 4,306  1-2 Beds  \
# 1  12300 Riata Trace Pky, Austin, TX 78727  $1,177 - 1,785     1 Bed
# 2       1300 Crossing Pl, Austin, TX 78741   Call for Rent    2 Beds
# 3   8800 N Interstate 35, Austin, TX 78753  $1,199 - 1,499     1 Bed
# 4    4711 E Riverside Dr, Austin, TX 78741  $1,399 - 1,699     1 Bed
#
#                                            amenities
# 0  Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 1  Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3  Fitness Center, Dishwasher, Refrigerator, In U...
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...

# %%
apartments_df['name'] = apartments_df['name'].str.replace(r',[^,]*$', '',regex=True).astype(str)
apartments_df['name'] = apartments_df['name'].str.replace(r',[^,]*$', '',regex=True).astype(str)

# %%
apartments_df.head(20)
# Out:
#                             name                                      address
# 0    The District on La Frontera      2811 La Frontera Blvd, Austin, TX 78728  \
# 1                          Riata      12300 Riata Trace Pky, Austin, TX 78727
# 2      Estates at East Riverside           1300 Crossing Pl, Austin, TX 78741
# 3           Starburst Apartments       8800 N Interstate 35, Austin, TX 78753
# 4               Edison Riverside        4711 E Riverside Dr, Austin, TX 78741
# 5                Bristol Heights            12041 Dessau Rd, Austin, TX 78754
# 6            Highline Apartments         13201 Legendary Dr, Austin, TX 78727
# 7                Midtown Commons         810 W St Johns Ave, Austin, TX 78752
# 8                     The Aspect           4900 E Oltorf St, Austin, TX 78741
# 9                 Bell Southpark  10500 S IH 35 Frontage Rd, Austin, TX 78748
# 10                         Terra      8300 Bluff Springs Rd, Austin, TX 78744
# 11                      44 South        4411 S Congress Ave, Austin, TX 78745
# 12        Brightleaf at Lakeline        14115 N Highway 183, Austin, TX 78717
# 13                    The Upland      12217 N Interstate 35, Austin, TX 78753
# 14                     Water Oak         12234 Heatherly Dr, Austin, TX 78747
# 15                  The Prescott        8200 S Congress Ave, Austin, TX 78745
# 16          Presidium Tech Ridge      12210 Tech Ridge Blvd, Austin, TX 78753
# 17                   Avery Ranch      9225 N Lake Creek Pky, Austin, TX 78717
# 18                   Three Hills         12001 Heatherly Dr, Austin, TX 78747
# 19  Crestview Commons Apartments            801 Sugaree Ave, Austin, TX 78757
#
#              price      beds
# 0   $1,354 - 4,306  1-2 Beds  \
# 1   $1,177 - 1,785     1 Bed
# 2    Call for Rent    2 Beds
# 3   $1,199 - 1,499     1 Bed
# 4   $1,399 - 1,699     1 Bed
# 5   $1,208 - 1,277  1-2 Beds
# 6   $1,325 - 1,900     1 Bed
# 7   $1,387 - 3,311     1 Bed
# 8   $1,417 - 1,517  1-2 Beds
# 9   $1,205 - 2,895     1 Bed
# 10  $1,193 - 3,764     1 Bed
# 11  $1,399 - 1,549  1-2 Beds
# 12  $1,460 - 1,695     1 Bed
# 13  $1,401 - 1,641  1-3 Beds
# 14  $1,305 - 1,909     1 Bed
# 15  $1,524 - 2,155     1 Bed
# 16  $1,495 - 1,515     1 Bed
# 17  $1,399 - 2,959     1 Bed
# 18  $1,370 - 2,766     1 Bed
# 19  $1,549 - 2,130     1 Bed
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, Dish...
# 1   Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Fitness Center, Dishwasher, Refrigerator, In U...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Maintenance on site, EV Ch...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Main...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 11  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 13  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 14  Dog & Cat Friendly, Stainless Steel Appliances...
# 15  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 17  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 18  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 19  Dog & Cat Friendly, Fitness Center, Pool, In U...

# %%
#Cleaning and Seperating Address Column
apartments_df[['street', 'city', 'state/zip']] = apartments_df['address'].str.split(',', expand=True)

# %%
apartments_df.head(20)
# Out:
#                             name                                      address
# 0    The District on La Frontera      2811 La Frontera Blvd, Austin, TX 78728  \
# 1                          Riata      12300 Riata Trace Pky, Austin, TX 78727
# 2      Estates at East Riverside           1300 Crossing Pl, Austin, TX 78741
# 3           Starburst Apartments       8800 N Interstate 35, Austin, TX 78753
# 4               Edison Riverside        4711 E Riverside Dr, Austin, TX 78741
# 5                Bristol Heights            12041 Dessau Rd, Austin, TX 78754
# 6            Highline Apartments         13201 Legendary Dr, Austin, TX 78727
# 7                Midtown Commons         810 W St Johns Ave, Austin, TX 78752
# 8                     The Aspect           4900 E Oltorf St, Austin, TX 78741
# 9                 Bell Southpark  10500 S IH 35 Frontage Rd, Austin, TX 78748
# 10                         Terra      8300 Bluff Springs Rd, Austin, TX 78744
# 11                      44 South        4411 S Congress Ave, Austin, TX 78745
# 12        Brightleaf at Lakeline        14115 N Highway 183, Austin, TX 78717
# 13                    The Upland      12217 N Interstate 35, Austin, TX 78753
# 14                     Water Oak         12234 Heatherly Dr, Austin, TX 78747
# 15                  The Prescott        8200 S Congress Ave, Austin, TX 78745
# 16          Presidium Tech Ridge      12210 Tech Ridge Blvd, Austin, TX 78753
# 17                   Avery Ranch      9225 N Lake Creek Pky, Austin, TX 78717
# 18                   Three Hills         12001 Heatherly Dr, Austin, TX 78747
# 19  Crestview Commons Apartments            801 Sugaree Ave, Austin, TX 78757
#
#              price      beds
# 0   $1,354 - 4,306  1-2 Beds  \
# 1   $1,177 - 1,785     1 Bed
# 2    Call for Rent    2 Beds
# 3   $1,199 - 1,499     1 Bed
# 4   $1,399 - 1,699     1 Bed
# 5   $1,208 - 1,277  1-2 Beds
# 6   $1,325 - 1,900     1 Bed
# 7   $1,387 - 3,311     1 Bed
# 8   $1,417 - 1,517  1-2 Beds
# 9   $1,205 - 2,895     1 Bed
# 10  $1,193 - 3,764     1 Bed
# 11  $1,399 - 1,549  1-2 Beds
# 12  $1,460 - 1,695     1 Bed
# 13  $1,401 - 1,641  1-3 Beds
# 14  $1,305 - 1,909     1 Bed
# 15  $1,524 - 2,155     1 Bed
# 16  $1,495 - 1,515     1 Bed
# 17  $1,399 - 2,959     1 Bed
# 18  $1,370 - 2,766     1 Bed
# 19  $1,549 - 2,130     1 Bed
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, Dish...  \
# 1   Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Fitness Center, Dishwasher, Refrigerator, In U...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Maintenance on site, EV Ch...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Main...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 11  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 13  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 14  Dog & Cat Friendly, Stainless Steel Appliances...
# 15  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 17  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 18  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 19  Dog & Cat Friendly, Fitness Center, Pool, In U...
#
#                        street     city  state/zip
# 0       2811 La Frontera Blvd   Austin   TX 78728
# 1       12300 Riata Trace Pky   Austin   TX 78727
# 2            1300 Crossing Pl   Austin   TX 78741
# 3        8800 N Interstate 35   Austin   TX 78753
# 4         4711 E Riverside Dr   Austin   TX 78741
# 5             12041 Dessau Rd   Austin   TX 78754
# 6          13201 Legendary Dr   Austin   TX 78727
# 7          810 W St Johns Ave   Austin   TX 78752
# 8            4900 E Oltorf St   Austin   TX 78741
# 9   10500 S IH 35 Frontage Rd   Austin   TX 78748
# 10      8300 Bluff Springs Rd   Austin   TX 78744
# 11        4411 S Congress Ave   Austin   TX 78745
# 12        14115 N Highway 183   Austin   TX 78717
# 13      12217 N Interstate 35   Austin   TX 78753
# 14         12234 Heatherly Dr   Austin   TX 78747
# 15        8200 S Congress Ave   Austin   TX 78745
# 16      12210 Tech Ridge Blvd   Austin   TX 78753
# 17      9225 N Lake Creek Pky   Austin   TX 78717
# 18         12001 Heatherly Dr   Austin   TX 78747
# 19            801 Sugaree Ave   Austin   TX 78757

# %%
apts_df_new = apartments_df['state/zip'].str.split(' ', expand=True)
apts_df_new.columns = ['index','state', 'zip']
apartments_df[['state','zipcode']] = apts_df_new[['state','zip']]
apartments_df = apartments_df.drop(columns=['state/zip'])

# %%
apartments_df.head()
# Out:
#                           name                                  address
# 0  The District on La Frontera  2811 La Frontera Blvd, Austin, TX 78728  \
# 1                        Riata  12300 Riata Trace Pky, Austin, TX 78727
# 2    Estates at East Riverside       1300 Crossing Pl, Austin, TX 78741
# 3         Starburst Apartments   8800 N Interstate 35, Austin, TX 78753
# 4             Edison Riverside    4711 E Riverside Dr, Austin, TX 78741
#
#             price      beds
# 0  $1,354 - 4,306  1-2 Beds  \
# 1  $1,177 - 1,785     1 Bed
# 2   Call for Rent    2 Beds
# 3  $1,199 - 1,499     1 Bed
# 4  $1,399 - 1,699     1 Bed
#
#                                            amenities                 street
# 0  Dog & Cat Friendly, Fitness Center, Pool, Dish...  2811 La Frontera Blvd  \
# 1  Dog & Cat Friendly, Fitness Center, In Unit Wa...  12300 Riata Trace Pky
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...       1300 Crossing Pl
# 3  Fitness Center, Dishwasher, Refrigerator, In U...   8800 N Interstate 35
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...    4711 E Riverside Dr
#
#       city state zipcode
# 0   Austin    TX   78728
# 1   Austin    TX   78727
# 2   Austin    TX   78741
# 3   Austin    TX   78753
# 4   Austin    TX   78741

# %%
#Cleaning Price Columns
apartments_df[['minprice', 'maxprice']] = apartments_df['price'].str.split('-', expand=True)
apartments_df['minprice'] = apartments_df['minprice'].str.replace('$','',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace('$','',)
apartments_df['minprice'] = apartments_df['minprice'].str.replace(',','',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace(',','',)
apartments_df = apartments_df.drop(columns=['price'])

# %%
apartments_df.head(10)
# Out:
#                           name                                      address
# 0  The District on La Frontera      2811 La Frontera Blvd, Austin, TX 78728  \
# 1                        Riata      12300 Riata Trace Pky, Austin, TX 78727
# 2    Estates at East Riverside           1300 Crossing Pl, Austin, TX 78741
# 3         Starburst Apartments       8800 N Interstate 35, Austin, TX 78753
# 4             Edison Riverside        4711 E Riverside Dr, Austin, TX 78741
# 5              Bristol Heights            12041 Dessau Rd, Austin, TX 78754
# 6          Highline Apartments         13201 Legendary Dr, Austin, TX 78727
# 7              Midtown Commons         810 W St Johns Ave, Austin, TX 78752
# 8                   The Aspect           4900 E Oltorf St, Austin, TX 78741
# 9               Bell Southpark  10500 S IH 35 Frontage Rd, Austin, TX 78748
#
#        beds                                          amenities
# 0  1-2 Beds  Dog & Cat Friendly, Fitness Center, Pool, Dish...  \
# 1     1 Bed  Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 2    2 Beds  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3     1 Bed  Fitness Center, Dishwasher, Refrigerator, In U...
# 4     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5  1-2 Beds  Dog & Cat Friendly, Maintenance on site, EV Ch...
# 6     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, Main...
# 8  1-2 Beds  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9     1 Bed  Dog & Cat Friendly, Fitness Center, Pool, In U...
#
#                       street     city state zipcode       minprice maxprice
# 0      2811 La Frontera Blvd   Austin    TX   78728          1354      4306
# 1      12300 Riata Trace Pky   Austin    TX   78727          1177      1785
# 2           1300 Crossing Pl   Austin    TX   78741  Call for Rent     None
# 3       8800 N Interstate 35   Austin    TX   78753          1199      1499
# 4        4711 E Riverside Dr   Austin    TX   78741          1399      1699
# 5            12041 Dessau Rd   Austin    TX   78754          1208      1277
# 6         13201 Legendary Dr   Austin    TX   78727          1325      1900
# 7         810 W St Johns Ave   Austin    TX   78752          1387      3311
# 8           4900 E Oltorf St   Austin    TX   78741          1417      1517
# 9  10500 S IH 35 Frontage Rd   Austin    TX   78748          1205      2895

# %%
apartments_df['minprice'] = apartments_df['minprice'].str.replace('Call for Rent','0',)
apartments_df['maxprice'] = apartments_df['maxprice'].str.replace('Call for Rent','0',)

# %%
#Cleaning bedroom column
apartments_df[['minbed', 'maxbed']] = apartments_df['beds'].str.split('-', expand=True)
apartments_df['minbed'] = apartments_df['minbed'].str.replace('Beds','',)
apartments_df['minbed'] = apartments_df['minbed'].str.replace('Bed','',)
apartments_df['maxbed'] = apartments_df['maxbed'].str.replace('Beds','',)
apartments_df['maxbed'] = apartments_df['maxbed'].str.replace('Bed','',)
apartments_df = apartments_df.drop(columns=['beds'])

# %%
apartments_df = apartments_df.fillna(0)

# %%
today = datetime.now()
print(today)
date = today.strftime("%d/%m/%Y %H:%M:%S")
date
# Out:
# 2023-10-25 20:16:50.926532
# '25/10/2023 20:16:50'

# %%
apartments_df['building_type'] = 'APT'
apartments_df['date'] = date

# %%
apartments_df.head(5)
# Out:
#                           name                                  address
# 0  The District on La Frontera  2811 La Frontera Blvd, Austin, TX 78728  \
# 1                        Riata  12300 Riata Trace Pky, Austin, TX 78727
# 2    Estates at East Riverside       1300 Crossing Pl, Austin, TX 78741
# 3         Starburst Apartments   8800 N Interstate 35, Austin, TX 78753
# 4             Edison Riverside    4711 E Riverside Dr, Austin, TX 78741
#
#                                            amenities                 street
# 0  Dog & Cat Friendly, Fitness Center, Pool, Dish...  2811 La Frontera Blvd  \
# 1  Dog & Cat Friendly, Fitness Center, In Unit Wa...  12300 Riata Trace Pky
# 2  Dog & Cat Friendly, Fitness Center, Pool, In U...       1300 Crossing Pl
# 3  Fitness Center, Dishwasher, Refrigerator, In U...   8800 N Interstate 35
# 4  Dog & Cat Friendly, Fitness Center, Pool, In U...    4711 E Riverside Dr
#
#       city state zipcode minprice maxprice minbed maxbed building_type
# 0   Austin    TX   78728    1354      4306      1     2            APT  \
# 1   Austin    TX   78727    1177      1785     1       0           APT
# 2   Austin    TX   78741        0        0     2       0           APT
# 3   Austin    TX   78753    1199      1499     1       0           APT
# 4   Austin    TX   78741    1399      1699     1       0           APT
#
#                   date
# 0  25/10/2023 20:16:50
# 1  25/10/2023 20:16:50
# 2  25/10/2023 20:16:50
# 3  25/10/2023 20:16:50
# 4  25/10/2023 20:16:50

# %%
apartments_df['city'].value_counts()
# Out:
# city
#  Austin          516
#  Pflugerville     15
#  Cedar Park       14
#  Round Rock        6
#  Del Valle         3
#  Manor             3
#  AUSTIN            2
#  Manchaca          1
# Name: count, dtype: int64

# %%
apartments_df.dtypes
# Out:
# name             object
# address          object
# amenities        object
# street           object
# city             object
# state            object
# zipcode          object
# minprice         object
# maxprice         object
# minbed           object
# maxbed           object
# building_type    object
# date             object
# dtype: object

# %%
convert_dict = {'minprice': float,
                'maxprice': float,
                'minbed': int,
                'maxbed': int,
                }
apartments_df = apartments_df.astype(convert_dict)
apartments_df['date'] = apartments_df['date'].astype('datetime64[ns]')
print(apartments_df.dtypes)
# Out:
# name                     object
# address                  object
# amenities                object
# street                   object
# city                     object
# state                    object
# zipcode                  object
# minprice                float64
# maxprice                float64
# minbed                    int64
# maxbed                    int64
# building_type            object
# date             datetime64[ns]
# dtype: object
# /var/folders/0k/r3nvlvy97cgdhjrb4v697trw0000gn/T/ipykernel_35461/1689935638.py:7: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   apartments_df['date'] = apartments_df['date'].astype('datetime64[ns]')

# %%
apartments_df.head(20)
# Out:
#                             name                                      address
# 0    The District on La Frontera      2811 La Frontera Blvd, Austin, TX 78728  \
# 1                          Riata      12300 Riata Trace Pky, Austin, TX 78727
# 2      Estates at East Riverside           1300 Crossing Pl, Austin, TX 78741
# 3           Starburst Apartments       8800 N Interstate 35, Austin, TX 78753
# 4               Edison Riverside        4711 E Riverside Dr, Austin, TX 78741
# 5                Bristol Heights            12041 Dessau Rd, Austin, TX 78754
# 6            Highline Apartments         13201 Legendary Dr, Austin, TX 78727
# 7                Midtown Commons         810 W St Johns Ave, Austin, TX 78752
# 8                     The Aspect           4900 E Oltorf St, Austin, TX 78741
# 9                 Bell Southpark  10500 S IH 35 Frontage Rd, Austin, TX 78748
# 10                         Terra      8300 Bluff Springs Rd, Austin, TX 78744
# 11                      44 South        4411 S Congress Ave, Austin, TX 78745
# 12        Brightleaf at Lakeline        14115 N Highway 183, Austin, TX 78717
# 13                    The Upland      12217 N Interstate 35, Austin, TX 78753
# 14                     Water Oak         12234 Heatherly Dr, Austin, TX 78747
# 15                  The Prescott        8200 S Congress Ave, Austin, TX 78745
# 16          Presidium Tech Ridge      12210 Tech Ridge Blvd, Austin, TX 78753
# 17                   Avery Ranch      9225 N Lake Creek Pky, Austin, TX 78717
# 18                   Three Hills         12001 Heatherly Dr, Austin, TX 78747
# 19  Crestview Commons Apartments            801 Sugaree Ave, Austin, TX 78757
#
#                                             amenities
# 0   Dog & Cat Friendly, Fitness Center, Pool, Dish...  \
# 1   Dog & Cat Friendly, Fitness Center, In Unit Wa...
# 2   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 3   Fitness Center, Dishwasher, Refrigerator, In U...
# 4   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 5   Dog & Cat Friendly, Maintenance on site, EV Ch...
# 6   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 7   Dog & Cat Friendly, Fitness Center, Pool, Main...
# 8   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 9   Dog & Cat Friendly, Fitness Center, Pool, In U...
# 10  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 11  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 12  Dog & Cat Friendly, Fitness Center, Pool, Elev...
# 13  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 14  Dog & Cat Friendly, Stainless Steel Appliances...
# 15  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 16  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 17  Dog & Cat Friendly, Fitness Center, Pool, In U...
# 18  Dog & Cat Friendly, Fitness Center, Pool, Club...
# 19  Dog & Cat Friendly, Fitness Center, Pool, In U...
#
#                        street     city state zipcode  minprice  maxprice
# 0       2811 La Frontera Blvd   Austin    TX   78728    1354.0    4306.0  \
# 1       12300 Riata Trace Pky   Austin    TX   78727    1177.0    1785.0
# 2            1300 Crossing Pl   Austin    TX   78741       0.0       0.0
# 3        8800 N Interstate 35   Austin    TX   78753    1199.0    1499.0
# 4         4711 E Riverside Dr   Austin    TX   78741    1399.0    1699.0
# 5             12041 Dessau Rd   Austin    TX   78754    1208.0    1277.0
# 6          13201 Legendary Dr   Austin    TX   78727    1325.0    1900.0
# 7          810 W St Johns Ave   Austin    TX   78752    1387.0    3311.0
# 8            4900 E Oltorf St   Austin    TX   78741    1417.0    1517.0
# 9   10500 S IH 35 Frontage Rd   Austin    TX   78748    1205.0    2895.0
# 10      8300 Bluff Springs Rd   Austin    TX   78744    1193.0    3764.0
# 11        4411 S Congress Ave   Austin    TX   78745    1399.0    1549.0
# 12        14115 N Highway 183   Austin    TX   78717    1460.0    1695.0
# 13      12217 N Interstate 35   Austin    TX   78753    1401.0    1641.0
# 14         12234 Heatherly Dr   Austin    TX   78747    1305.0    1909.0
# 15        8200 S Congress Ave   Austin    TX   78745    1524.0    2155.0
# 16      12210 Tech Ridge Blvd   Austin    TX   78753    1495.0    1515.0
# 17      9225 N Lake Creek Pky   Austin    TX   78717    1399.0    2959.0
# 18         12001 Heatherly Dr   Austin    TX   78747    1370.0    2766.0
# 19            801 Sugaree Ave   Austin    TX   78757    1549.0    2130.0
#
#     minbed  maxbed building_type                date
# 0        1       2           APT 2023-10-25 20:16:50
# 1        1       0           APT 2023-10-25 20:16:50
# 2        2       0           APT 2023-10-25 20:16:50
# 3        1       0           APT 2023-10-25 20:16:50
# 4        1       0           APT 2023-10-25 20:16:50
# 5        1       2           APT 2023-10-25 20:16:50
# 6        1       0           APT 2023-10-25 20:16:50
# 7        1       0           APT 2023-10-25 20:16:50
# 8        1       2           APT 2023-10-25 20:16:50
# 9        1       0           APT 2023-10-25 20:16:50
# 10       1       0           APT 2023-10-25 20:16:50
# 11       1       2           APT 2023-10-25 20:16:50
# 12       1       0           APT 2023-10-25 20:16:50
# 13       1       3           APT 2023-10-25 20:16:50
# 14       1       0           APT 2023-10-25 20:16:50
# 15       1       0           APT 2023-10-25 20:16:50
# 16       1       0           APT 2023-10-25 20:16:50
# 17       1       0           APT 2023-10-25 20:16:50
# 18       1       0           APT 2023-10-25 20:16:50
# 19       1       0           APT 2023-10-25 20:16:50

# %%
e = today.strftime("%d.%m.%Y")
print(e)
fname = "./Addresses/addresses_{}.xlsx".format(e)
print(fname)
apartments_df.to_excel(fname)
# Out:
# 25.10.2023
# ./Addresses/addresses_25.10.2023.xlsx

# %% [markdown]
# SAVE TABLE TO SQL

# %%
hostname = 'localhost'
database = 'geo'
username = 'postgres'
pwd = '032197An'
port_id = 5432

# %%
try:    
    conn = psycopg2.connect(
        host = hostname,
        dbname = database,
        user = username,
        password = pwd,
        port = port_id)
except Exception as error:
    print(error)

# %%
cur = conn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
#Created a new database to in SQL to store the date
#cur.execute('CREATE DATABASE austin')

# %%
#Deleted any tables named austin if they existed
#cur.execute('DROP TABLE IF EXISTS apartments')

# %%
#Created new table in database to collect the data in the dataframe
#cur.execute("CREATE TABLE IF NOT EXISTS apartments (name VARCHAR(256), address VARCHAR(256),amenities VARCHAR(256), street VARCHAR(256), city VARCHAR(256), state VARCHAR(5), zipcode VARCHAR(10), minprice FLOAT, maxprice FLOAT, minbed INT, maxbed INT, building_type VARCHAR(5), date TIMESTAMP)")

# %%
#Need to research more about this,
engine = create_engine('postgresql+psycopg2://postgres:032197An@localhost/geo')
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/geo)

# %%
apartments_df.to_sql('austin_apartments', engine, if_exists='append', index=False)
# Out:
# 560

# %%
conn.commit
# Out:
# <function connection.commit>

# %%
conn.close()
